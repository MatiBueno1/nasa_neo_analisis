# %%
import pandas as pd
from sqlalchemy import create_engine
from dotenv import load_dotenv
import os

# %%
load_dotenv()

df = pd.read_csv("../data/processed/neo_clean.csv")
df["close_approach_date"] = pd.to_datetime(df["close_approach_date"])
print(df.shape)
df.head()
# Out:
# (79439, 8)
#         id                name  is_potentially_hazardous  diameter_km_min  \
# 0  3516633           (2010 HA)                     False         0.044112
# 1  3837644          (2019 AY3)                     False         0.045767
# 2  3843493           (2019 PY)                     False         0.023150
# 3  2446862  446862 (2001 VB76)                      True         0.208236
# 4  3765015         (2016 WR48)                     False         0.160160
#
#    diameter_km_max close_approach_date  miss_distance_km  velocity_kmh
# 0         0.098637          1995-01-07      2.959363e+07  22395.337325
# 1         0.102339          1995-01-07      1.909375e+07  80679.829203
# 2         0.051765          1995-01-07      1.440650e+07  17995.842471
# 3         0.465629          1995-01-08      7.622845e+06  27326.492203
# 4         0.358129          1995-01-08      4.339162e+07  26721.139515

# %%
DATABASE_URL = os.getenv("DATABASE_URL")
engine = create_engine(DATABASE_URL)

# %%
with engine.connect() as connection:
    print("Conexión exitosa")
# Out:
# Conexión exitosa

# %%
df.to_sql(
    name="close_approaches",
    con=engine,
    if_exists="replace",
    index=False
)

print("Tabla cargada correctamente")
# Out:
# Tabla cargada correctamente
